# %%
import pandas as pd
import os
import joblib
import shutil
import numpy as np
import cv2

from pathlib import Path
from ipynb.fs.full.preprocessing_image import preprocessing_img
from sklearn.preprocessing import LabelEncoder
from imutils import build_montages

# %%
dataset_dir = Path('dataset').resolve()
dicts_temp = {}
df_dataset = pd.DataFrame(columns=['file_path'])

for path, subdirs, files in os.walk(dataset_dir):
    for filename in files:
        if filename.endswith('.png'):
            dicts_temp['file_path'] = Path(os.path.join(path, filename))
            df_temp = pd.DataFrame([dicts_temp])
            df_dataset = pd.concat([df_dataset, df_temp], ignore_index=True)

df_dataset['image_code']    = df_dataset['file_path'].map(lambda x: x.stem)
df_dataset['disease']       = df_dataset['file_path'].map(lambda x: x.parent.stem)
df_dataset['validation']    = df_dataset['file_path'].map(lambda x: x.parent.parent.stem)
df_dataset['geometry_type'] = df_dataset['file_path'].map(lambda x: x.parent.parent.parent.stem)

# %%
df_wave_dataset = pd.DataFrame()
df_wave_dataset = df_dataset.loc[(df_dataset['validation'] == 'testing') & (df_dataset['geometry_type'] == 'wave')]
df_wave_dataset = df_wave_dataset.reset_index()
(test_X, test_Y) = preprocessing_img(df_wave_dataset, False)
# Out:
# testing data load:   0%|          | 0/30 [00:00<?, ?it/s]

# %%
df_wave_dataset
# Out:
#     index                                          file_path image_code  \
# 0     102  C:\Users\ZHENGYU\Desktop\P2\dataset\wave\testi...    V01HO01
# 1     103  C:\Users\ZHENGYU\Desktop\P2\dataset\wave\testi...    V02HO01
# 2     104  C:\Users\ZHENGYU\Desktop\P2\dataset\wave\testi...    V03HO01
# 3     105  C:\Users\ZHENGYU\Desktop\P2\dataset\wave\testi...    V04HO01
# 4     106  C:\Users\ZHENGYU\Desktop\P2\dataset\wave\testi...    V05HO01
# 5     107  C:\Users\ZHENGYU\Desktop\P2\dataset\wave\testi...    V06HO01
# 6     108  C:\Users\ZHENGYU\Desktop\P2\dataset\wave\testi...    V07HO01
# 7     109  C:\Users\ZHENGYU\Desktop\P2\dataset\wave\testi...    V08HO01
# 8     110  C:\Users\ZHENGYU\Desktop\P2\dataset\wave\testi...    V09HO01
# 9     111  C:\Users\ZHENGYU\Desktop\P2\dataset\wave\testi...    V10HO01
# 10    112  C:\Users\ZHENGYU\Desktop\P2\dataset\wave\testi...    V11HO01
# 11    113  C:\Users\ZHENGYU\Desktop\P2\dataset\wave\testi...    V55HO08
# 12    114  C:\Users\ZHENGYU\Desktop\P2\dataset\wave\testi...    V55HO09
# 13    115  C:\Users\ZHENGYU\Desktop\P2\dataset\wave\testi...    V55HO10
# 14    116  C:\Users\ZHENGYU\Desktop\P2\dataset\wave\testi...    V55HO11
# 15    117  C:\Users\ZHENGYU\Desktop\P2\dataset\wave\testi...    V01PO01
# 16    118  C:\Users\ZHENGYU\Desktop\P2\dataset\wave\testi...    V02PO01
# 17    119  C:\Users\ZHENGYU\Desktop\P2\dataset\wave\testi...    V03PO01
# 18    120  C:\Users\ZHENGYU\Desktop\P2\dataset\wave\testi...    V03PO04
# 19    121  C:\Users\ZHENGYU\Desktop\P2\dataset\wave\testi...    V03PO07
# 20    122  C:\Users\ZHENGYU\Desktop\P2\dataset\wave\testi...    V04PO01
# 21    123  C:\Users\ZHENGYU\Desktop\P2\dataset\wave\testi...    V05PO01
# 22    124  C:\Users\ZHENGYU\Desktop\P2\dataset\wave\testi...    V06PO01
# 23    125  C:\Users\ZHENGYU\Desktop\P2\dataset\wave\testi...    V07PO01
# 24    126  C:\Users\ZHENGYU\Desktop\P2\dataset\wave\testi...    V08PO01
# 25    127  C:\Users\ZHENGYU\Desktop\P2\dataset\wave\testi...    V09PO01
# 26    128  C:\Users\ZHENGYU\Desktop\P2\dataset\wave\testi...    V10PO01
# 27    129  C:\Users\ZHENGYU\Desktop\P2\dataset\wave\testi...    V11PO01
# 28    130  C:\Users\ZHENGYU\Desktop\P2\dataset\wave\testi...    V14PO01
# 29    131  C:\Users\ZHENGYU\Desktop\P2\dataset\wave\testi...    V14PO03
#
#       disease validation geometry_type
# 0     healthy    testing          wave
# 1     healthy    testing          wave
# 2     healthy    testing          wave
# 3     healthy    testing          wave
# 4     healthy    testing          wave
# 5     healthy    testing          wave
# 6     healthy    testing          wave
# 7     healthy    testing          wave
# 8     healthy    testing          wave
# 9     healthy    testing          wave
# 10    healthy    testing          wave
# 11    healthy    testing          wave
# 12    healthy    testing          wave
# 13    healthy    testing          wave
# 14    healthy    testing          wave
# 15  parkinson    testing          wave
# 16  parkinson    testing          wave
# 17  parkinson    testing          wave
# 18  parkinson    testing          wave
# 19  parkinson    testing          wave
# 20  parkinson    testing          wave
# 21  parkinson    testing          wave
# 22  parkinson    testing          wave
# 23  parkinson    testing          wave
# 24  parkinson    testing          wave
# 25  parkinson    testing          wave
# 26  parkinson    testing          wave
# 27  parkinson    testing          wave
# 28  parkinson    testing          wave
# 29  parkinson    testing          wave

# %%
model_joblib = joblib.load('./model/finalized_wave_model.joblib')

# encode the labels as integers
le = LabelEncoder()
train_Y = test_Y
train_Y = le.fit_transform(train_Y)
test_Y = le.transform(test_Y)

pred_Y = model_joblib.predict(test_X)
label = le.inverse_transform(pred_Y)
df_wave_dataset = pd.concat([df_wave_dataset, pd.DataFrame(label, columns = ['pred_Y'])], axis=1)

# %%
df_wave_dataset
# Out:
#     index                                          file_path image_code  \
# 0     102  C:\Users\ZHENGYU\Desktop\P2\dataset\wave\testi...    V01HO01
# 1     103  C:\Users\ZHENGYU\Desktop\P2\dataset\wave\testi...    V02HO01
# 2     104  C:\Users\ZHENGYU\Desktop\P2\dataset\wave\testi...    V03HO01
# 3     105  C:\Users\ZHENGYU\Desktop\P2\dataset\wave\testi...    V04HO01
# 4     106  C:\Users\ZHENGYU\Desktop\P2\dataset\wave\testi...    V05HO01
# 5     107  C:\Users\ZHENGYU\Desktop\P2\dataset\wave\testi...    V06HO01
# 6     108  C:\Users\ZHENGYU\Desktop\P2\dataset\wave\testi...    V07HO01
# 7     109  C:\Users\ZHENGYU\Desktop\P2\dataset\wave\testi...    V08HO01
# 8     110  C:\Users\ZHENGYU\Desktop\P2\dataset\wave\testi...    V09HO01
# 9     111  C:\Users\ZHENGYU\Desktop\P2\dataset\wave\testi...    V10HO01
# 10    112  C:\Users\ZHENGYU\Desktop\P2\dataset\wave\testi...    V11HO01
# 11    113  C:\Users\ZHENGYU\Desktop\P2\dataset\wave\testi...    V55HO08
# 12    114  C:\Users\ZHENGYU\Desktop\P2\dataset\wave\testi...    V55HO09
# 13    115  C:\Users\ZHENGYU\Desktop\P2\dataset\wave\testi...    V55HO10
# 14    116  C:\Users\ZHENGYU\Desktop\P2\dataset\wave\testi...    V55HO11
# 15    117  C:\Users\ZHENGYU\Desktop\P2\dataset\wave\testi...    V01PO01
# 16    118  C:\Users\ZHENGYU\Desktop\P2\dataset\wave\testi...    V02PO01
# 17    119  C:\Users\ZHENGYU\Desktop\P2\dataset\wave\testi...    V03PO01
# 18    120  C:\Users\ZHENGYU\Desktop\P2\dataset\wave\testi...    V03PO04
# 19    121  C:\Users\ZHENGYU\Desktop\P2\dataset\wave\testi...    V03PO07
# 20    122  C:\Users\ZHENGYU\Desktop\P2\dataset\wave\testi...    V04PO01
# 21    123  C:\Users\ZHENGYU\Desktop\P2\dataset\wave\testi...    V05PO01
# 22    124  C:\Users\ZHENGYU\Desktop\P2\dataset\wave\testi...    V06PO01
# 23    125  C:\Users\ZHENGYU\Desktop\P2\dataset\wave\testi...    V07PO01
# 24    126  C:\Users\ZHENGYU\Desktop\P2\dataset\wave\testi...    V08PO01
# 25    127  C:\Users\ZHENGYU\Desktop\P2\dataset\wave\testi...    V09PO01
# 26    128  C:\Users\ZHENGYU\Desktop\P2\dataset\wave\testi...    V10PO01
# 27    129  C:\Users\ZHENGYU\Desktop\P2\dataset\wave\testi...    V11PO01
# 28    130  C:\Users\ZHENGYU\Desktop\P2\dataset\wave\testi...    V14PO01
# 29    131  C:\Users\ZHENGYU\Desktop\P2\dataset\wave\testi...    V14PO03
#
#       disease validation geometry_type     pred_Y
# 0     healthy    testing          wave    healthy
# 1     healthy    testing          wave    healthy
# 2     healthy    testing          wave  parkinson
# 3     healthy    testing          wave    healthy
# 4     healthy    testing          wave  parkinson
# 5     healthy    testing          wave  parkinson
# 6     healthy    testing          wave    healthy
# 7     healthy    testing          wave  parkinson
# 8     healthy    testing          wave    healthy
# 9     healthy    testing          wave    healthy
# 10    healthy    testing          wave    healthy
# 11    healthy    testing          wave    healthy
# 12    healthy    testing          wave    healthy
# 13    healthy    testing          wave    healthy
# 14    healthy    testing          wave    healthy
# 15  parkinson    testing          wave    healthy
# 16  parkinson    testing          wave  parkinson
# 17  parkinson    testing          wave  parkinson
# 18  parkinson    testing          wave  parkinson
# 19  parkinson    testing          wave  parkinson
# 20  parkinson    testing          wave  parkinson
# 21  parkinson    testing          wave  parkinson
# 22  parkinson    testing          wave  parkinson
# 23  parkinson    testing          wave  parkinson
# 24  parkinson    testing          wave    healthy
# 25  parkinson    testing          wave  parkinson
# 26  parkinson    testing          wave  parkinson
# 27  parkinson    testing          wave  parkinson
# 28  parkinson    testing          wave  parkinson
# 29  parkinson    testing          wave    healthy

# %%
Path("./result/parkinson").mkdir(parents = True, exist_ok = True)
Path("./result/healthy").mkdir(parents = True, exist_ok = True)
Path("./output").mkdir(parents = True, exist_ok = True)

# %%
for index, row in df_wave_dataset.iterrows():
    source = row['file_path']
    destination = Path('result/' + row['pred_Y']).resolve()/source.name
    shutil.copyfile(str(source), str(destination))

# %%
# randomly select a few images and then initialize the output images
# for the montage
idxs = np.arange(0, len(df_wave_dataset))
idxs = np.random.choice(idxs, size=(25,), replace=False)
selected_images = []

# %%
for i in idxs:
    # load the testing image, clone it, and resize it
    img_input = cv2.imread(str(df_wave_dataset['file_path'][i]))
    img_output = img_input.copy()
    img_output = cv2.resize(img_output, (128, 128))
    
    # draw the colored class label on the output image and add it to
    # the set of output images
    label = df_wave_dataset['pred_Y'][i]
    color = (0, 255, 0) if label == "healthy" else (0, 0, 255)
    cv2.putText(img_output, label, (3, 20), cv2.FONT_HERSHEY_SIMPLEX, 0.5,
        color, 2)
    selected_images.append(img_output)

# %%
# create a montage using 128x128 "tiles" with 5 rows and 5 columns
montage = build_montages(selected_images, (128, 128), (5, 5))[0]

# %%
# Filename
filename = './output/wave_prediction_result.jpg'
cv2.imwrite(filename, montage)
# Out:
# True

# %%
# show the output montage
cv2.imshow("Wave Prediction Result", montage)
cv2.waitKey(0)
cv2.destroyAllWindows()
